# %%
import os
import numpy as np
import pandas as pd
import scipy.stats as st
import wandb
import matplotlib.pyplot as plt
from typing import Literal
from dotenv import load_dotenv

wandb_api_key = load_dotenv("../../.env", override=True)
wandb.login(key=os.getenv("WANDB_API_KEY"))

# A script to retrieve experiments from weights and biases for making plots and tables
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/billy/.netrc
# wandb: Currently logged in as: billy-vale (aisurrey_photoacoustics) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
def get_metrics_dict(
    df : pd.DataFrame, 
    run_notes : list,
    metrics_dict : dict,
    convert_m_to_cm : bool=True,
    verbose : bool=False,
    use_average : Literal['mean_std', 'median_iqr'] = 'mean_std'
    ) -> dict:
    notes_dict = {notes : metrics_dict.copy() for notes in run_notes}
    for notes in run_notes:
        # get each fold this notes was pretrained using the synthetic data
        notes_df = df.loc[df['Notes'] == notes]
        if notes_df.shape[0] != 5:
            if verbose:
                print(f'notes_df.shape[0] != 5 for notes {notes}, actual shape: {notes_df.shape}')
                print('getting 5 most recent runs')
            notes_df = notes_df.sort_values(by='Created', ascending=False).head(5)
            
        for metric in metrics_dict.keys():
            metric_values = notes_df[metric].values
            if verbose:
                print(f'{notes} {metric} {metric_values}')
            if convert_m_to_cm and ('mean_RMSE' in metric or 'mean_MAE' in metric):
                # convert from m^{-1} to cm^{-1}
                metric_values = metric_values * 1e-2
            # calculate mean and std or median and iqr
            try:
                if use_average == 'mean_std':
                    notes_dict[notes][metric] = [np.mean(metric_values), np.std(metric_values)]
                elif use_average == 'median_iqr':
                    median = np.median(metric_values)
                    q1 = np.percentile(metric_values, 25)
                    q3 = np.percentile(metric_values, 75)
                    iqr = q3 - q1
                    notes_dict[notes][metric] = [median, iqr]
            except Exception as e:
                print(notes_df)
                print(f'notes_df.shape: {notes_df.shape}')
                raise Exception(f'Error for notes {notes}, metric {metric}: {e}')
    return notes_dict

# %%
def print_single_tex_reslts_table(models_dict : dict, caption : str,
                                  label : str, metric_headers : str) -> None:
    metrics = list(list(models_dict.values())[0].keys())
    models = list(models_dict.keys())
    tex_table_string = f"""\\begin{{table*}}
    \\centering
    \\caption{caption}
    \\setlength{{\\tabcolsep}}{{3pt}}
    %\\begin{{tabular}}{{|p{{25pt}}|p{{75pt}}|p{{115pt}}|}}
    \\begin{{tabular}}{{|l|l|l|l|l|l|l|}}
    \\hline
    Model & """ + metric_headers + """ \\\\
    \\hline"""
    for model in models:
        row_name = '{' + model.replace('_',' ') + '}'
        tex_table_string += f"""\\multirow{{2}}{{*}}{row_name} & ${models_dict[model][metrics[0]][0]:.3f}$"""
        for metric in metrics[1:]:
            tex_table_string += f""" & ${models_dict[model][metric][0]:.3f}$"""
        tex_table_string += f""" \\\\ \n"""
        for metric in metrics:
            tex_table_string += f""" & $\\pm{models_dict[model][metric][1]:.3f}$"""
        tex_table_string += f""" \\\\ 
        \\hline"""
    tex_table_string += f"""\\end{{tabular}}
    \\label{label}
    \\end{{table*}}
    
    """
    
    print(tex_table_string)

# %%
def print_double_tex_reslts_table(models_dict_left : dict, header_left : str,
                                  models_dict_right : dict, header_right : str,
                                  caption : str, label : str, metric_headers : str,
                                  header_len : str='{3}') -> None:
    metrics_left = list(list(models_dict_left.values())[0].keys())
    metrics_right = list(list(models_dict_right.values())[0].keys())
    models = list(models_dict_left.keys()) # both dicts must have the same models
    tex_table_string = f"""\\begin{{table*}}
    \\centering
    \\caption{caption}
    \\label{{table}}
    \\setlength{{\\tabcolsep}}{{3pt}}
    %\\begin{{tabular}}{{|p{{25pt}}|p{{75pt}}|p{{115pt}}|}}
    \\resizebox{{\\textwidth}}{{!}}""" + """{""" + f"""\\begin{{tabular}}""" + """{{|l|"""

    for i in range(2*int(header_len[1])):
        tex_table_string += f"""l|"""
    tex_table_string += """}}"""
    
    tex_table_string += f"""
    \\hline
    \\multirow{{2}}{{*}}{{Model}} & \\multicolumn{header_len}{{|l|}}{header_left} & \\multicolumn{header_len}{{|l|}}{header_right} \\\\
    \\cline{{2-{str(int(header_len[1])*2+1)}}}
    & """ + metric_headers + """ & """ + metric_headers + """ \\\\
    \\hline"""
    for model in models:
        row_name = '{' + model.replace('_',' ') + '}'
        tex_table_string += f"""\\multirow{{2}}{{*}}{row_name} & ${models_dict_left[model][metrics_left[0]][0]:.3f}$"""
        for metric in metrics_left[1:]:
            tex_table_string += f""" & ${models_dict_left[model][metric][0]:.3f}$"""
        tex_table_string += f"""\n"""
        for metric in metrics_right:
            tex_table_string += f""" & ${models_dict_right[model][metric][0]:.3f}$"""
        tex_table_string += f""" \\\\ \n"""
        for metric in metrics_left:
            tex_table_string += f""" & $\\pm{models_dict_left[model][metric][1]:.3f}$"""
        tex_table_string += f"""\n"""
        for metric in metrics_right:
            tex_table_string += f""" & $\\pm{models_dict_right[model][metric][1]:.3f}$"""
        tex_table_string += f""" \\\\ 
        \\hline"""
    tex_table_string += f"""\\end{{tabular}}""" + """}""" + f"""
    \\label{label}
    \\end{{table*}}
    
    """
    
    print(tex_table_string)

# %%
if __name__ == "__main__":
    # wandb.login() not needed - credentials stored in ~/.netrc from terminal login
    api = wandb.Api(timeout=6000)

    # Optional: Filter by tags, state, etc. (see W&B API docs)
    FILTER = {}  # You can use {"state": "finished"} to get only completed runs

    # Project is specified by <entity/project-name>
    runs = api.runs("aisurrey_photoacoustics/MSOT_EDM2", filters=FILTER)

# %%
if __name__ == "__main__":
    run_notes = [
        'e2eQPAT_Janeks_weights', # no loss curves for pretrained weights
        'experimental_from_scratch_UNet_e2eQPAT',
        'experimental_from_scratch_UNet_e2eQPAT_fixedseed',
        'e2eQPAT_fine_tune',
        'e2eQPAT_fine_tune_no_shuffle',
        'e2eQPAT_boft3_fine_tune',
        'e2eQPAT_fine_tune_lr1em5_l2reg1em1',
        'e2eQPAT_fine_tune_lr1em5',
        'experimental_from_scratch_UNet_diffusion_ablation',
        'experimental_from_scratch_UNet_diffusion_ablation_deeperunet',
        'experimental_from_scratch_UNet_diffusion_ablation_ema',
        'experimental_from_scratch_UNet_wl_pos_emb',
        'EDM2_fine_tune',
        'EDM2_fine_tune_lr1em3',
        'EDM2_fine_tune_lr1em3_test',
        'EDM2_fine_tune2_lr1em3',
        'EDM2_fine_tune_lr1em2_l2reg1em1',
        'EDM2_fine_tune_lr1em3_l2reg1em1',
        'EDM2_fine_tune_lr1em3_l2reg1',
        'EDM2_fine_tune_lr1em3_l2reg1_test',
        'EDM2_fine_tune_lr1em3_l2reg10',
        'EDM2_fine_tune_lr1em3_l2reg100',
        'experimental_from_scratch_EDM2',
        'experimental_from_scratch_EDM2_lr1em3',
        'experimental_from_scratch_EDM2_lr1em3_test',
        'digimouse_extrusion_test',
        'digimouse_test',
    ]
    
    run_dict_list = []
    history_dict = {}
    for run in runs:
        
        if run.notes not in run_notes:
            continue

        if run.notes not in (history_dict.keys()):
            history_dict[run.notes] = {}

        history_dict[run.notes][run.name] = {'mean_train_loss' : run.history(
            x_axis='_step', keys=['mean_train_loss'], stream='default', pandas=True
        )}
        history_dict[run.notes][run.name]['mean_experimental_train_loss'] = run.history(
            x_axis='_step', keys=['mean_experimental_train_loss'], stream='default', pandas=True,
        )
        history_dict[run.notes][run.name]['mean_experimental_val_loss'] = run.history(
            x_axis='_step', keys=['mean_experimental_val_loss'], stream='default', pandas=True,
        )

        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        run_dict_list.append(run.summary._json_dict)
        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        run_dict_list[-1].update(
            {k: v for k,v in run.config.items() if not k.startswith('_')}
        )
        # .name is the human-readable name of the run.
        run_dict_list[-1]['Name'] = run.name
        run_dict_list[-1]['Notes'] = run.notes
        run_dict_list[-1]['Created'] = run.createdAt
        
    df = pd.DataFrame(run_dict_list)

    # Preview the result
    print(df.head())

    columns = df.columns.values
# Out:
#         _runtime   _step    _timestamp               _wandb  \
# 0  127283.197837  361533  1.763706e+09  {'runtime': 127283}
# 1  128089.871350  361533  1.763708e+09  {'runtime': 128090}
# 2  129843.934592  361533  1.763711e+09  {'runtime': 129844}
# 3  129263.980979  361533  1.763712e+09  {'runtime': 129264}
# 4  127540.831311  361533  1.763781e+09  {'runtime': 127541}
#
#    bg_experimental_test_mean_MAE  bg_experimental_test_mean_PSNR  \
# 0                       0.044191                        4.912240
# 1                       0.031130                        4.226144
# 2                       0.030113                        6.131927
# 3                       0.031268                        5.874666
# 4                       0.031749                        4.777763
#
#   bg_experimental_test_mean_R2  bg_experimental_test_mean_RMSE  \
# 0                    -Infinity                        0.073382
# 1                    -Infinity                        0.077458
# 2                    -Infinity                        0.062857
# 3                    -Infinity                        0.066216
# 4                    -Infinity                        0.073836
#
#    bg_experimental_test_mean_Rel_Err  bg_experimental_test_mean_SSIM  ...  \
# 0                          42.674876                        0.024087  ...
# 1                          29.736222                        0.008127  ...
# 2                          27.599250                        0.018158  ...
# 3                          28.917121                        0.013744  ...
# 4                          28.402156                        0.017516  ...
#
#    bg_synthetic_test_std_PSNR  bg_synthetic_test_std_R2  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   bg_synthetic_test_std_RMSE  bg_synthetic_test_std_Rel_Err  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    bg_synthetic_test_std_SSIM  synthetic_test_fluence_loss  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    synthetic_test_mu_a_loss  synthetic_test_time  \
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#   synthetic_test_time_per_batch  synthetic_test_tot_loss
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
# [5 rows x 158 columns]

# %%
if __name__ == "__main__":
    api = wandb.Api()

    # Optional: Filter by tags, state, etc. (see W&B API docs)
    FILTER = {}  # You can use {"state": "finished"} to get only completed runs

    # Project is specified by <entity/project-name>
    runs = api.runs("aisurrey_photoacoustics/MSOT_Diffusion", filters=FILTER)

    notes = [
        'experimental_from_scratch_UNet_e2eQPAT_fixedseed_9bd6c0b',
        'e2eQPAT_fine_tune_and_pretained_with_amsgrad_lr1em4_eps1em8',
        'e2eQPAT_from_scratch_amsgrad_lrem4_eps1em8',
    ]

    run_dict_list = []
    for run in runs:
        if run.notes not in notes:
            continue

        if run.notes not in (history_dict.keys()):
            history_dict[run.notes] = {}

        history_dict[run.notes][run.name] = {'mean_train_loss' : run.history(
            x_axis='_step', keys=['mean_train_loss'], stream='default', pandas=True
        )}
        history_dict[run.notes][run.name]['mean_experimental_train_loss'] = run.history(
            x_axis='_step', keys=['mean_experimental_train_loss'], stream='default', pandas=True,
        )
        history_dict[run.notes][run.name]['mean_experimental_val_loss'] = run.history(
            x_axis='_step', keys=['mean_experimental_val_loss'], stream='default', pandas=True,
        )

        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        run_dict_list.append(run.summary._json_dict)
        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        run_dict_list[-1].update(
            {k: v for k,v in run.config.items() if not k.startswith('_')}
        )
        # .name is the human-readable name of the run.
        run_dict_list[-1]['Name'] = run.name
        run_dict_list[-1]['Notes'] = run.notes
        run_dict_list[-1]['Created'] = run.createdAt
        
    df = pd.concat([df, pd.DataFrame(run_dict_list)], ignore_index=True)

    # Preview the result
    print(df.head())

    columns = df.columns.values
# Out:
#         _runtime   _step    _timestamp               _wandb  \
# 0  127283.197837  361533  1.763706e+09  {'runtime': 127283}
# 1  128089.871350  361533  1.763708e+09  {'runtime': 128090}
# 2  129843.934592  361533  1.763711e+09  {'runtime': 129844}
# 3  129263.980979  361533  1.763712e+09  {'runtime': 129264}
# 4  127540.831311  361533  1.763781e+09  {'runtime': 127541}
#
#    bg_experimental_test_mean_MAE  bg_experimental_test_mean_PSNR  \
# 0                       0.044191                        4.912240
# 1                       0.031130                        4.226144
# 2                       0.030113                        6.131927
# 3                       0.031268                        5.874666
# 4                       0.031749                        4.777763
#
#   bg_experimental_test_mean_R2  bg_experimental_test_mean_RMSE  \
# 0                    -Infinity                        0.073382
# 1                    -Infinity                        0.077458
# 2                    -Infinity                        0.062857
# 3                    -Infinity                        0.066216
# 4                    -Infinity                        0.073836
#
#    bg_experimental_test_mean_Rel_Err  bg_experimental_test_mean_SSIM  ...  \
# 0                          42.674876                        0.024087  ...
# 1                          29.736222                        0.008127  ...
# 2                          27.599250                        0.018158  ...
# 3                          28.917121                        0.013744  ...
# 4                          28.402156                        0.017516  ...
#
#    bg_synthetic_test_std_RMSE  bg_synthetic_test_std_Rel_Err  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#   bg_synthetic_test_std_SSIM  synthetic_test_fluence_loss  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#    synthetic_test_mu_a_loss  synthetic_test_time  \
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#    synthetic_test_time_per_batch  synthetic_test_tot_loss test_time  \
# 0                            NaN                      NaN       NaN
# 1                            NaN                      NaN       NaN
# 2                            NaN                      NaN       NaN
# 3                            NaN                      NaN       NaN
# 4                            NaN                      NaN       NaN
#
#    test_time_per_batch
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 160 columns]

# %%
# results for experimental test dataset
if __name__ == "__main__":
    run_notes = [
        'e2eQPAT_Janeks_weights', # no loss curves for pretrained weights
        'experimental_from_scratch_UNet_e2eQPAT',
        'experimental_from_scratch_UNet_e2eQPAT_fixedseed',
        'experimental_from_scratch_UNet_e2eQPAT_fixedseed_9bd6c0b',
        'e2eQPAT_fine_tune',
        'e2eQPAT_fine_tune_no_shuffle',
        'e2eQPAT_boft3_fine_tune',
        'e2eQPAT_fine_tune_lr1em5_l2reg1em1',
        'e2eQPAT_fine_tune_lr1em5',
        'experimental_from_scratch_UNet_diffusion_ablation',
        'experimental_from_scratch_UNet_diffusion_ablation_deeperunet',
        'experimental_from_scratch_UNet_diffusion_ablation_ema',
        'experimental_from_scratch_UNet_wl_pos_emb',
        'EDM2_fine_tune',
        #'EDM2_fine_tune_lr1em3',
        'EDM2_fine_tune_lr1em3_test',
        'EDM2_fine_tune2_lr1em3',
        'EDM2_fine_tune_lr1em2_l2reg1em1',
        'EDM2_fine_tune_lr1em3_l2reg1em1',
        #'EDM2_fine_tune_lr1em3_l2reg1',
        'EDM2_fine_tune_lr1em3_l2reg1_test',
        'EDM2_fine_tune_lr1em3_l2reg10',
        'EDM2_fine_tune_lr1em3_l2reg100',
        'experimental_from_scratch_EDM2',
        #'experimental_from_scratch_EDM2_lr1em3',
        'experimental_from_scratch_EDM2_lr1em3_test',
    ]
    inclusion_metrics_dict = {
        'inclusion_experimental_test_mean_RMSE' : [None]*5,
        'inclusion_experimental_test_mean_Rel_Err' : [None]*5,
        'inclusion_experimental_test_mean_PSNR' : [None]*5,
    }
    bg_metrics_dict = {
        'bg_experimental_test_mean_RMSE' : [None]*5,
        'bg_experimental_test_mean_Rel_Err' : [None]*5,
        'bg_experimental_test_mean_PSNR' : [None]*5,
    }    
    metric_headers = """RMSE (cm$^{{-1}}$) & Rel. Error (\\%) & PSNR"""

    bg_metrics_models_dict = get_metrics_dict(
        df, run_notes, bg_metrics_dict, convert_m_to_cm=False, use_average='mean_std'
        #df, run_notes, bg_metrics_dict, convert_m_to_cm=False, use_average='median_iqr'
    )
    
    inclusion_metrics_models_dict = get_metrics_dict(
        df, run_notes, inclusion_metrics_dict, convert_m_to_cm=False, use_average='mean_std'
        #df, run_notes, inclusion_metrics_dict, convert_m_to_cm=False, use_average='median_iqr'
    )

    print_double_tex_reslts_table(
        bg_metrics_models_dict,
        '{Background}',
        inclusion_metrics_models_dict, 
        '{Inclusions}',
        '{Experimental test dataset. Mean and standard deviation of 5 runs.}',
        #'{Experimental test dataset. Median and interquartile range of 5 runs.}',
        '{tab:experimental_test_metrics}',
        metric_headers
    )
# Out:
# \begin{table*}
#     \centering
#     \caption{Experimental test dataset. Mean and standard deviation of 5 runs.}
#     \label{table}
#     \setlength{\tabcolsep}{3pt}
#     %\begin{tabular}{|p{25pt}|p{75pt}|p{115pt}|}
#     \resizebox{\textwidth}{!}{\begin{tabular}{{|l|l|l|l|l|l|l|}}
#     \hline
#     \multirow{2}{*}{Model} & \multicolumn{3}{|l|}{Background} & \multicolumn{3}{|l|}{Inclusions} \\
#     \cline{2-7}
#     & RMSE (cm$^{{-1}}$) & Rel. Error (\%) & PSNR & RMSE (cm$^{{-1}}$) & Rel. Error (\%) & PSNR \\
#     \hline\multirow{2}{*}{e2eQPAT Janeks weights} & $0.092$ & $48.706$ & $2.030$
#  & $0.708$ & $34.237$ & $8.849$ \\
#  & $\pm0.005$ & $\pm2.702$ & $\pm0.551$
#  & $\pm0.028$ & $\pm2.524$ & $\pm0.604$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet e2eQPAT} & $0.099$ & $52.690$ & $1.421$
#  & $0.707$ & $35.423$ & $8.542$ \\
#  & $\pm0.009$ & $\pm4.214$ & $\pm0.756$
#  & $\pm0.072$ & $\pm5.389$ & $\pm1.091$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet e2eQPAT fixedseed} & $0.104$ & $53.382$ & $1.163$
#  & $0.622$ & $34.048$ & $9.215$ \\
#  & $\pm0.014$ & $\pm8.952$ & $\pm1.094$
#  & $\pm0.098$ & $\pm4.457$ & $\pm1.235$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet e2eQPAT fixedseed 9bd6c0b} & $0.100$ & $51.418$ & $1.637$
#  & $0.628$ & $32.449$ & $9.516$ \\
#  & $\pm0.016$ & $\pm7.019$ & $\pm1.227$
#  & $\pm0.072$ & $\pm2.780$ & $\pm0.845$ \\
#         \hline\multirow{2}{*}{e2eQPAT fine tune} & $0.110$ & $55.561$ & $0.967$
#  & $0.641$ & $35.477$ & $8.541$ \\
#  & $\pm0.006$ & $\pm2.835$ & $\pm0.241$
#  & $\pm0.043$ & $\pm3.053$ & $\pm0.726$ \\
#         \hline\multirow{2}{*}{e2eQPAT fine tune no shuffle} & $0.096$ & $51.339$ & $1.912$
#  & $0.629$ & $31.881$ & $9.148$ \\
#  & $\pm0.006$ & $\pm3.662$ & $\pm0.495$
#  & $\pm0.028$ & $\pm1.859$ & $\pm0.496$ \\
#         \hline\multirow{2}{*}{e2eQPAT boft3 fine tune} & $0.122$ & $68.441$ & $-0.135$
#  & $0.644$ & $37.188$ & $8.485$ \\
#  & $\pm0.006$ & $\pm3.429$ & $\pm0.416$
#  & $\pm0.037$ & $\pm3.367$ & $\pm0.740$ \\
#         \hline\multirow{2}{*}{e2eQPAT fine tune lr1em5 l2reg1em1} & $0.117$ & $63.399$ & $0.512$
#  & $0.736$ & $41.092$ & $7.359$ \\
#  & $\pm0.009$ & $\pm4.190$ & $\pm0.434$
#  & $\pm0.018$ & $\pm2.439$ & $\pm0.368$ \\
#         \hline\multirow{2}{*}{e2eQPAT fine tune lr1em5} & $0.117$ & $62.986$ & $0.453$
#  & $0.716$ & $40.010$ & $7.588$ \\
#  & $\pm0.010$ & $\pm4.441$ & $\pm0.635$
#  & $\pm0.034$ & $\pm3.022$ & $\pm0.571$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet diffusion ablation} & $0.119$ & $62.332$ & $0.465$
#  & $0.628$ & $36.989$ & $8.885$ \\
#  & $\pm0.026$ & $\pm11.527$ & $\pm1.803$
#  & $\pm0.056$ & $\pm4.913$ & $\pm0.863$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet diffusion ablation deeperunet} & $0.132$ & $72.049$ & $-0.180$
#  & $0.615$ & $34.901$ & $9.302$ \\
#  & $\pm0.033$ & $\pm12.026$ & $\pm1.746$
#  & $\pm0.069$ & $\pm2.915$ & $\pm0.935$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet diffusion ablation ema} & $0.127$ & $70.845$ & $0.140$
#  & $0.588$ & $33.987$ & $9.539$ \\
#  & $\pm0.013$ & $\pm5.289$ & $\pm0.730$
#  & $\pm0.076$ & $\pm3.157$ & $\pm0.897$ \\
#         \hline\multirow{2}{*}{experimental from scratch UNet wl pos emb} & $0.113$ & $60.132$ & $1.307$
#  & $0.676$ & $41.022$ & $8.276$ \\
#  & $\pm0.029$ & $\pm10.513$ & $\pm1.844$
#  & $\pm0.090$ & $\pm3.074$ & $\pm0.867$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune} & $0.071$ & $31.466$ & $5.185$
#  & $0.609$ & $29.459$ & $10.559$ \\
#  & $\pm0.005$ & $\pm5.647$ & $\pm0.712$
#  & $\pm0.079$ & $\pm3.482$ & $\pm0.772$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em3 test} & $0.063$ & $30.501$ & $6.105$
#  & $0.570$ & $26.994$ & $10.853$ \\
#  & $\pm0.005$ & $\pm2.145$ & $\pm0.802$
#  & $\pm0.044$ & $\pm2.504$ & $\pm0.705$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune2 lr1em3} & $nan$ & $nan$ & $nan$
#  & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em2 l2reg1em1} & $0.063$ & $29.924$ & $6.218$
#  & $0.657$ & $35.074$ & $9.171$ \\
#  & $\pm0.005$ & $\pm1.569$ & $\pm0.549$
#  & $\pm0.068$ & $\pm3.147$ & $\pm0.775$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em3 l2reg1em1} & $0.067$ & $34.069$ & $5.620$
#  & $0.568$ & $27.707$ & $10.839$ \\
#  & $\pm0.004$ & $\pm2.674$ & $\pm0.656$
#  & $\pm0.044$ & $\pm2.380$ & $\pm0.656$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em3 l2reg1 test} & $0.064$ & $30.363$ & $6.012$
#  & $0.565$ & $26.817$ & $10.936$ \\
#  & $\pm0.003$ & $\pm1.072$ & $\pm0.552$
#  & $\pm0.041$ & $\pm2.449$ & $\pm0.664$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em3 l2reg10} & $0.063$ & $30.125$ & $6.075$
#  & $0.568$ & $27.206$ & $10.834$ \\
#  & $\pm0.004$ & $\pm1.391$ & $\pm0.675$
#  & $\pm0.042$ & $\pm2.427$ & $\pm0.661$ \\
#         \hline\multirow{2}{*}{EDM2 fine tune lr1em3 l2reg100} & $nan$ & $nan$ & $nan$
#  & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{experimental from scratch EDM2} & $0.065$ & $31.068$ & $5.627$
#  & $0.657$ & $31.294$ & $10.144$ \\
#  & $\pm0.007$ & $\pm1.646$ & $\pm0.954$
#  & $\pm0.076$ & $\pm4.077$ & $\pm0.931$ \\
#         \hline\multirow{2}{*}{experimental from scratch EDM2 lr1em3 test} & $0.073$ & $43.739$ & $4.612$
#  & $0.699$ & $31.242$ & $9.843$ \\
#  & $\pm0.006$ & $\pm3.274$ & $\pm0.764$
#  & $\pm0.044$ & $\pm2.659$ & $\pm0.565$ \\
#         \hline\end{tabular}}
#     \label{tab:experimental_test_metrics}
#     \end{table*}

# %%
# results for pretraining on imagenet synthetic dataset
if __name__ == "__main__":
    run_notes = [
        'pretrain_UNet_e2eQPAT',
        'pretrain_UNet_e2eQPAT_fixedseed',
        'pretrain_EDM2',
        'pretrain_UNet_wl_pos_emb',
        'pretrain_UNet_diffusion_ablation',
    ]
    bg_metrics_dict = {
        'bg_synthetic_test_mean_RMSE' : [None]*5,
        'bg_synthetic_test_mean_Rel_Err' : [None]*5,
        'bg_synthetic_test_mean_PSNR' : [None]*5,
    }    
    metric_headers = """RMSE (cm$^{{-1}}$) & Rel. Error (\\%) & PSNR"""

    bg_metrics_models_dict = get_metrics_dict(
        df, run_notes, bg_metrics_dict, convert_m_to_cm=False
    )
    
    print_single_tex_reslts_table(
        bg_metrics_models_dict,
        '{Synthetic test dataset. Mean and standard deviation of 5 runs.}',
        '{tab:imagenet_test_metrics}',
        metric_headers
    )
# Out:
# \begin{table*}
#     \centering
#     \caption{Synthetic test dataset. Mean and standard deviation of 5 runs.}
#     \setlength{\tabcolsep}{3pt}
#     %\begin{tabular}{|p{25pt}|p{75pt}|p{115pt}|}
#     \begin{tabular}{|l|l|l|l|l|l|l|}
#     \hline
#     Model & RMSE (cm$^{{-1}}$) & Rel. Error (\%) & PSNR \\
#     \hline\multirow{2}{*}{pretrain UNet e2eQPAT} & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{pretrain UNet e2eQPAT fixedseed} & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{pretrain EDM2} & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{pretrain UNet wl pos emb} & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\multirow{2}{*}{pretrain UNet diffusion ablation} & $nan$ & $nan$ & $nan$ \\
#  & $\pmnan$ & $\pmnan$ & $\pmnan$ \\
#         \hline\end{tabular}
#     \label{tab:imagenet_test_metrics}
#     \end{table*}

# %%
import matplotlib.pyplot as plt

run_notes = [
    #'e2eQPAT_Janeks_weights', # no loss curves for pretrained weights
    #'experimental_from_scratch_UNet_e2eQPAT',
    #'experimental_from_scratch_UNet_e2eQPAT_fixedseed',
    #'experimental_from_scratch_UNet_e2eQPAT_fixedseed_9bd6c0b',
    ###'e2eQPAT_from_scratch_amsgrad_lrem4_eps1em8', # <- final choice
    ###'e2eQPAT_fine_tune_and_pretained_with_amsgrad_lr1em4_eps1em8', # <- final choice
    #'e2eQPAT_fine_tune',
    #'e2eQPAT_fine_tune_no_shuffle',
    #'e2eQPAT_boft3_fine_tune',
    #'e2eQPAT_fine_tune_lr1em5_l2reg1em1',
    #'e2eQPAT_fine_tune_lr1em5',
    #'experimental_from_scratch_UNet_diffusion_ablation',
    #'experimental_from_scratch_UNet_diffusion_ablation_deeperunet',
    #'experimental_from_scratch_UNet_diffusion_ablation_ema',
    #'experimental_from_scratch_UNet_wl_pos_emb',
    'experimental_from_scratch_EDM2_lr1em3', # <- final choice
    #'experimental_from_scratch_EDM2_lr1em3_test',
    #'EDM2_fine_tune',
    #'EDM2_fine_tune_lr1em3',
    #'EDM2_fine_tune_lr1em3_test',
    #'EDM2_fine_tune2_lr1em3',
    #'EDM2_fine_tune_lr1em2_l2reg1em1',
    #'EDM2_fine_tune_lr1em3_l2reg1em1',
    'EDM2_fine_tune_lr1em3_l2reg1', # <- final choice
    #'EDM2_fine_tune_lr1em3_l2reg1_test',
    #'experimental_from_scratch_EDM2',
    
]

epochs = 1000
separate_ax_for_labels = True

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
ax.set_yscale('log')
ax.set_ylabel(r'Mean Squared Error (a.u.)')
#ax.set_xlabel('Steps')
ax.set_xlabel('Epochs')

labels = ['from scratch EDM2', 'fine tune EDM2']
#labels = ['from scratch U-Net', 'fine tune U-Net']
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow', 'teal']
#lines = ['-', '--', '-.', ':']
if __name__ == "__main__":
    for i, notes in enumerate(run_notes):
        notes_history = history_dict[notes]
        for j, fold in enumerate(['fold0', 'fold1', 'fold2', 'fold3', 'fold4']):
            for key in list(notes_history.keys()):
                if fold in key:
                    notes_fold_history = notes_history[key]
                    break
            
            if fold == 'fold0':
                val_loss_steps = notes_fold_history['mean_experimental_val_loss']['_step'].values
                val_loss_steps = val_loss_steps * epochs / np.max(val_loss_steps)
                try:
                    train_loss_key = 'mean_experimental_train_loss'
                    train_loss_steps =  notes_fold_history['mean_experimental_train_loss']['_step'].values
                except:
                    train_loss_key = 'mean_train_loss'
                    train_loss_steps =  notes_fold_history['mean_train_loss']['_step'].values
                train_loss_steps = train_loss_steps * epochs / np.max(train_loss_steps)
            
                train_loss = np.full((5, len(train_loss_steps)), dtype=np.float32, fill_value=np.nan)
                val_loss = np.full((5, len(val_loss_steps)), dtype=np.float32, fill_value=np.nan)

            # handles cases where some folds have different lengths of training
            fold_train_loss = notes_fold_history[train_loss_key][train_loss_key].values
            fold_val_loss = notes_fold_history['mean_experimental_val_loss']['mean_experimental_val_loss'].values
            train_loss[j, :len(fold_train_loss)] = fold_train_loss
            val_loss[j, :len(fold_val_loss)] = fold_val_loss
                    
        #ax.plot(train_loss_steps, np.nanmean(train_loss, axis=0), color=colors[i], linestyle='-', label=f'{labels[i]} train loss')
        #ax.plot(val_loss_steps, np.nanmean(val_loss, axis=0), color=colors[i], linestyle='--', label=f'{labels[i]}, validation loss')
        # fill between min and max for train and val loss
        #ax.fill_between(train_loss_steps, np.nanmin(train_loss, axis=0), np.nanmax(train_loss, axis=0), color=colors[i], alpha=0.2)
        #ax.fill_between(val_loss_steps, np.nanmin(val_loss, axis=0), np.nanmax(val_loss, axis=0), color=colors[i], alpha=0.2)
        
        # plot median train and val loss
        ax.plot(train_loss_steps, np.nanmedian(train_loss, axis=0), color=colors[i], linestyle='-', label=f'{labels[i]} train loss')
        ax.plot(val_loss_steps, np.nanmedian(val_loss, axis=0), color=colors[i], linestyle='--', label=f'{labels[i]}, validation loss')
        # fill between 25th and 75th percentile for train and val loss
        ax.fill_between(train_loss_steps, np.nanpercentile(train_loss, 25, axis=0), np.nanpercentile(train_loss, 75, axis=0), color=colors[i], alpha=0.2)
        ax.fill_between(val_loss_steps, np.nanpercentile(val_loss, 25, axis=0), np.nanpercentile(val_loss, 75, axis=0), color=colors[i], alpha=0.2)
        
    ax.legend(loc='upper right')
    ax.set_xlim(0, epochs)
    #ax.set_ylim(1e-5, 10)
    ax.grid(True)
    ax.set_axisbelow(True)
    fig.tight_layout()

    fig.savefig('loss_curves.png')
    fig.savefig('loss_curves.svg')

# %%
if __name__ == "__main__":
    # wandb.login() not needed - credentials stored in ~/.netrc from terminal login
    api = wandb.Api(timeout=6000)

    # Optional: Filter by tags, state, etc. (see W&B API docs)
    FILTER = {}  # You can use {"state": "finished"} to get only completed runs

    # Project is specified by <entity/project-name>
    runs = api.runs("aisurrey_photoacoustics/MSOT_EDM2", filters=FILTER)
    run_notes = [
        'digimouse_extrusion_test',
        'digmouse_test',
    ]
    digimouse_run_dict_list = []
    for run in runs:
        
        if run.notes not in run_notes:
            continue
        
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        digimouse_run_dict_list.append(run.summary._json_dict)
        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        digimouse_run_dict_list[-1].update(
            {k: v for k,v in run.config.items() if not k.startswith('_')}
        )
        # .name is the human-readable name of the run.
        digimouse_run_dict_list[-1]['Name'] = run.name
        digimouse_run_dict_list[-1]['Notes'] = run.notes
        digimouse_run_dict_list[-1]['Created'] = run.createdAt
        
    digimouse_df = pd.DataFrame(digimouse_run_dict_list)

    # Preview the result
    print(df.head())

    columns = df.columns.values
# Out:
#      _runtime  _step    _timestamp            _wandb  \
# 0  173.726512     27  1.769074e+09  {'runtime': 174}
# 1  173.851161     27  1.769074e+09  {'runtime': 174}
# 2  178.146680     27  1.769074e+09  {'runtime': 178}
# 3  173.850993     27  1.769074e+09  {'runtime': 174}
# 4  174.862644     27  1.769074e+09  {'runtime': 175}
#
#    bg_synthetic_test_mean_MAE  bg_synthetic_test_mean_PSNR  \
# 0                    8.827728                    17.117679
# 1                   11.419255                    14.158063
# 2                    9.000107                    16.414588
# 3                    7.928615                    18.173945
# 4                    7.709867                    18.583609
#
#    bg_synthetic_test_mean_R2  bg_synthetic_test_mean_RMSE  \
# 0                  -4.771417                    10.010089
# 1                 -10.810404                    12.440936
# 2                  -7.425029                    10.310535
# 3                  -3.786039                     9.380606
# 4                  -3.062868                     9.105700
#
#    bg_synthetic_test_mean_Rel_Err  bg_synthetic_test_mean_SSIM  ...  \
# 0                       24.983028                     0.742516  ...
# 1                       32.818952                     0.711560  ...
# 2                       30.163058                     0.702588  ...
# 3                       23.370447                     0.712904  ...
# 4                       21.713917                     0.734006  ...
#
#    data_normalisation  save_test_examples  \
# 0            standard                True
# 1            standard                True
# 2            standard                True
# 3            standard                True
# 4            standard                True
#
#                                   synthetic_root_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#                                  load_checkpoint_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#                                experimental_root_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#    phema_reconstruction_std  synthetic_or_experimental        Name  \
# 0                      0.07                  synthetic  EDM2_fold0
# 1                      0.07                  synthetic  EDM2_fold0
# 2                      0.07                  synthetic  EDM2_fold0
# 3                      0.07                  synthetic  EDM2_fold0
# 4                      0.07                  synthetic  EDM2_fold0
#
#                       Notes               Created
# 0  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 1  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 2  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 3  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 4  digimouse_extrusion_test  2026-01-22T09:25:45Z
#
# [5 rows x 55 columns]

# %%
digimouse_df
# Out:
#      _runtime  _step    _timestamp            _wandb  \
# 0  170.699216     27  1.769074e+09  {'runtime': 171}
# 1  170.033227     27  1.769074e+09  {'runtime': 170}
# 2  174.344398     27  1.769074e+09  {'runtime': 175}
# 3  172.889900     27  1.769074e+09  {'runtime': 173}
# 4  175.071548     27  1.769074e+09  {'runtime': 175}
# 5  173.726512     27  1.769074e+09  {'runtime': 174}
# 6  173.851161     27  1.769074e+09  {'runtime': 174}
# 7  178.146680     27  1.769074e+09  {'runtime': 178}
# 8  173.850993     27  1.769074e+09  {'runtime': 174}
# 9  174.862644     27  1.769074e+09  {'runtime': 175}
#
#    bg_synthetic_test_mean_MAE  bg_synthetic_test_mean_PSNR  \
# 0                   10.869773                    14.422870
# 1                   10.524176                    14.579388
# 2                   12.423131                    13.062336
# 3                   10.997284                    13.861387
# 4                   12.491049                    12.512050
# 5                    8.827728                    17.117679
# 6                   11.419255                    14.158063
# 7                    9.000107                    16.414588
# 8                    7.928615                    18.173945
# 9                    7.709867                    18.583609
#
#    bg_synthetic_test_mean_R2  bg_synthetic_test_mean_RMSE  \
# 0                  -7.105831                    13.312874
# 1                  -8.259574                    13.151543
# 2                 -10.759218                    14.537692
# 3                 -10.296908                    13.766396
# 4                 -22.133495                    15.138339
# 5                  -4.771417                    10.010089
# 6                 -10.810404                    12.440936
# 7                  -7.425029                    10.310535
# 8                  -3.786039                     9.380606
# 9                  -3.062868                     9.105700
#
#    bg_synthetic_test_mean_Rel_Err  bg_synthetic_test_mean_SSIM  ...  \
# 0                       38.033907                     0.441958  ...
# 1                       35.413089                     0.449310  ...
# 2                       46.171826                     0.449003  ...
# 3                       36.270652                     0.448288  ...
# 4                       38.387541                     0.445907  ...
# 5                       24.983028                     0.742516  ...
# 6                       32.818952                     0.711560  ...
# 7                       30.163058                     0.702588  ...
# 8                       23.370447                     0.712904  ...
# 9                       21.713917                     0.734006  ...
#
#    data_normalisation  save_test_examples  \
# 0            standard                True
# 1            standard                True
# 2            standard                True
# 3            standard                True
# 4            standard                True
# 5            standard                True
# 6            standard                True
# 7            standard                True
# 8            standard                True
# 9            standard                True
#
#                                   synthetic_root_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 5  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 6  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 7  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 8  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 9  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#                                  load_checkpoint_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 5  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 6  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 7  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 8  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 9  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#                                experimental_root_dir  \
# 0  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 1  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 2  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 3  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 4  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 5  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 6  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 7  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 8  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
# 9  /mnt/fast/nobackup/users/wv00017/MSOT_diffusio...
#
#    phema_reconstruction_std  synthetic_or_experimental        Name  \
# 0                      0.07                  synthetic  EDM2_fold0
# 1                      0.07                  synthetic  EDM2_fold0
# 2                      0.07                  synthetic  EDM2_fold0
# 3                      0.07                  synthetic  EDM2_fold0
# 4                      0.07                  synthetic  EDM2_fold0
# 5                      0.07                  synthetic  EDM2_fold0
# 6                      0.07                  synthetic  EDM2_fold0
# 7                      0.07                  synthetic  EDM2_fold0
# 8                      0.07                  synthetic  EDM2_fold0
# 9                      0.07                  synthetic  EDM2_fold0
#
#                       Notes               Created
# 0             digmouse_test  2026-01-22T09:25:41Z
# 1             digmouse_test  2026-01-22T09:25:41Z
# 2             digmouse_test  2026-01-22T09:25:43Z
# 3             digmouse_test  2026-01-22T09:25:44Z
# 4             digmouse_test  2026-01-22T09:25:44Z
# 5  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 6  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 7  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 8  digimouse_extrusion_test  2026-01-22T09:25:45Z
# 9  digimouse_extrusion_test  2026-01-22T09:25:45Z
#
# [10 rows x 55 columns]

# %%
# results for digimouse test dataset
if __name__ == "__main__":
    run_notes = [
        'digmouse_test',
        'digimouse_extrusion_test',
    ]
    bg_metrics_dict = {
        'bg_synthetic_test_mean_RMSE' : [None]*5,
        'bg_synthetic_test_mean_Rel_Err' : [None]*5,
        'bg_synthetic_test_mean_PSNR' : [None]*5,
    }    
    metric_headers = """RMSE (cm$^{{-1}}$) & Rel. Error (\\%) & PSNR"""

    metrics_models_dict = get_metrics_dict(
        digimouse_df, run_notes, bg_metrics_dict, convert_m_to_cm=True, use_average='mean_std',
        #df, ['digimouse_test'], bg_metrics_dict, convert_m_to_cm=False, use_average='median_iqr'
    )
    
    print_single_tex_reslts_table(
        metrics_models_dict,
        '{Mean and standard deviation of 5 runs.}',
        '{tab:digimouse_test_metrics}',
        metric_headers
    )
    
    # metrics_models_dict_extrusion = get_metrics_dict(
    #     df, run_notes, inclusion_metrics_dict, convert_m_to_cm=False, use_average='mean_std'
    #     #df, ['digimouse_extrusion_test'], inclusion_metrics_dict, convert_m_to_cm=False, use_average='median_iqr'
    # )

    # print_double_tex_reslts_table(
    #     bg_metrics_models_dict,
    #     '{Background}',
    #     inclusion_metrics_models_dict, 
    #     '{Inclusions}',
    #     #'{Experimental test dataset. Mean and standard deviation of 5 runs.}',
    #     '{Experimental test dataset. Median and interquartile range of 5 runs.}',
    #     '{tab:experimental_test_metrics}',
    #     metric_headers
    # )
# Out:
# \begin{table*}
#     \centering
#     \caption{Mean and standard deviation of 5 runs.}
#     \setlength{\tabcolsep}{3pt}
#     %\begin{tabular}{|p{25pt}|p{75pt}|p{115pt}|}
#     \begin{tabular}{|l|l|l|l|l|l|l|}
#     \hline
#     Model & RMSE (cm$^{{-1}}$) & Rel. Error (\%) & PSNR \\
#     \hline\multirow{2}{*}{digmouse test} & $0.140$ & $38.855$ & $13.688$ \\
#  & $\pm0.008$ & $\pm3.820$ & $\pm0.792$ \\
#         \hline\multirow{2}{*}{digimouse extrusion test} & $0.102$ & $26.610$ & $16.890$ \\
#  & $\pm0.012$ & $\pm4.202$ & $\pm1.566$ \\
#         \hline\end{tabular}
#     \label{tab:digimouse_test_metrics}
#     \end{table*}
